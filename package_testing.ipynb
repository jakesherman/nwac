# %%
# %pip uninstall -y nwac
# Out:
# Found existing installation: nwac 0.1.0
# Uninstalling nwac-0.1.0:
#   Successfully uninstalled nwac-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -e .
# Out:
# Obtaining file:///Users/jake.sherman/Documents/nwac
# Requirement already satisfied: pandas in /Users/jake.sherman/opt/anaconda3/lib/python3.8/site-packages (from nwac==0.1.0) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/jake.sherman/opt/anaconda3/lib/python3.8/site-packages (from pandas->nwac==0.1.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/jake.sherman/opt/anaconda3/lib/python3.8/site-packages (from pandas->nwac==0.1.0) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/jake.sherman/opt/anaconda3/lib/python3.8/site-packages (from pandas->nwac==0.1.0) (1.19.5)
# Requirement already satisfied: six>=1.5 in /Users/jake.sherman/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->nwac==0.1.0) (1.15.0)
# Installing collected packages: nwac
#   Running setup.py develop for nwac
# Successfully installed nwac
# Note: you may need to restart the kernel to use updated packages.

# %%
from nwac import stations, download_historical_data

# %%
stations()
# Out:
#     Station_Id                             Name  Elevation  \
# 0            1                    Alpental Base       3100
# 1            2            Alpental Mid-Mountain       4350
# 2            3                  Alpental Summit       5470
# 3            4                  Hurricane Ridge       5250
# 4            5       Mt Baker - Heather Meadows       4210
# 5            6              Mt Baker - Pan Dome       5020
# 6            7                           Mazama       2170
# 7            8             Washington Pass Base       5450
# 8            9            Washington Pass Upper       6680
# 9           10                Dirty Face Summit       5980
# 10          11                   Lake Wenatchee       1930
# 11          12                  Berne Snow Camp       2700
# 12          13      Stevens Pass - Schmidt Haus       3950
# 13          14       Stevens Pass - Grace Lakes       4800
# 14          17           Stevens Pass - Skyline       5250
# 15          18           Stevens Pass - Skyline       5250
# 16          19                Tumwater Mountain       4180
# 17          20                    Mt Washington       4340
# 18          21                  Snoqualmie Pass       3010
# 19          22    Snoqualmie Pass - Dodge Ridge       3760
# 20          23      Snoqualmie Pass - East Shed       3770
# 21          24               Mission Ridge Base       4610
# 22          25             Mission Ridge Summit       6730
# 23          26       Mission Ridge Mid-Mountain       5160
# 24          27             Crystal Green Valley       6230
# 25          28                     Crystal Base       4570
# 26          29                   Crystal Summit       6830
# 27          30                    Sunrise Upper       6880
# 28          31                     Sunrise Base       6410
# 29          32              Chinook Pass Summit       6240
# 30          33                Chinook Pass Base       5500
# 31          34                        Camp Muir      10110
# 32          35                         Paradise       5400
# 33          36                    Paradise Wind       5380
# 34          37                  White Pass Base       4470
# 35          39                 White Pass Upper       5800
# 36          40        Mt St Helens - Coldwater        3260
# 37          41  Mt Hood Meadows Cascade Express       7300
# 38          42             Mt Hood Meadows Blue       6540
# 39          43             Mt Hood Meadows Base       5380
# 40          44                 Timberline Lodge       5880
# 41          45            Timberline Magic Mile       6990
# 42          46                    Ski Bowl Base       3660
# 43          47                  Ski Bowl Summit       5010
# 44          48                     Blewett Pass       4100
# 45          49          White Pass Pigtail Peak       5970
# 46          50            Stevens Pass - Brooks       4800
#
#                           Location  Start_Date
# 0                  Snoqualmie Pass  2014-10-11
# 1                  Snoqualmie Pass  2014-12-04
# 2                  Snoqualmie Pass  2014-01-03
# 3                         Olympics  2014-09-23
# 4                         Mt Baker  2014-09-23
# 5                         Mt Baker  2014-09-23
# 6                  Washington Pass  2014-01-01
# 7                  Washington Pass  2014-09-23
# 8                  Washington Pass  2014-09-23
# 9   Lake Wenatchee - Mission Ridge  2014-09-23
# 10  Lake Wenatchee - Mission Ridge  2014-09-23
# 11                        Mt Baker  2014-09-23
# 12                    Stevens Pass  2014-09-23
# 13                    Stevens Pass  2014-11-28
# 14                    Stevens Pass  2014-12-23
# 15                    Stevens Pass  2014-12-17
# 16  Lake Wenatchee - Mission Ridge  2014-09-23
# 17                 Snoqualmie Pass  2014-08-01
# 18                 Snoqualmie Pass  2014-08-01
# 19                 Snoqualmie Pass  2014-08-01
# 20                 Snoqualmie Pass  2014-08-01
# 21  Lake Wenatchee - Mission Ridge  2014-01-01
# 22  Lake Wenatchee - Mission Ridge  2014-09-23
# 23  Lake Wenatchee - Mission Ridge  2014-09-23
# 24                      Mt Rainier  2015-01-12
# 25                      Mt Rainier  2014-09-23
# 26                      Mt Rainier  2014-02-02
# 27                      Mt Rainier  2014-09-23
# 28                      Mt Rainier  2014-04-05
# 29                      Mt Rainier  2014-09-23
# 30                      Mt Rainier  2014-09-23
# 31                      Mt Rainier  2014-09-23
# 32                      Mt Rainier  2014-09-23
# 33                      Mt Rainier  2014-09-23
# 34                      White Pass  2020-10-14
# 35                      White Pass  2014-09-23
# 36                    Mt St Helens  2014-09-23
# 37                         Mt Hood  2014-01-03
# 38                         Mt Hood  2014-09-23
# 39                         Mt Hood  2014-09-23
# 40                         Mt Hood  2014-09-23
# 41                         Mt Hood  2014-09-23
# 42                         Mt Hood  2014-10-30
# 43                         Mt Hood  2015-01-08
# 44  Lake Wenatchee - Mission Ridge  2014-10-22
# 45                      White Pass  2014-09-23
# 46                    Stevens Pass  2015-11-26

# %%
hurricane_ridge_2022_1 = download_historical_data(
    station_ids=[4],
    years=[2021, 2022]
)

hurricane_ridge_2022_1
# Out:
#       Station_Id     Station_Name            Date_Time  Battery_Voltage  \
# 0              4  Hurricane Ridge  2021-12-31 23:00:00             13.2
# 1              4  Hurricane Ridge  2021-12-31 22:00:00             13.2
# 2              4  Hurricane Ridge  2021-12-31 21:00:00             13.2
# 3              4  Hurricane Ridge  2021-12-31 20:00:00             13.2
# 4              4  Hurricane Ridge  2021-12-31 19:00:00             13.2
# ...          ...              ...                  ...              ...
# 6131           4  Hurricane Ridge  2022-01-01 04:00:00             13.2
# 6132           4  Hurricane Ridge  2022-01-01 03:00:00             13.2
# 6133           4  Hurricane Ridge  2022-01-01 02:00:00             13.2
# 6134           4  Hurricane Ridge  2022-01-01 01:00:00             13.2
# 6135           4  Hurricane Ridge  2022-01-01 00:00:00             13.2
#
#         Temp  Relative_Humidity  Precipitation  Total_Snow_Depth  \
# 0      7.331               82.1            0.0            234.10
# 1      5.482               83.1            0.0            234.10
# 2      5.383               82.0            0.0            234.10
# 3      5.132               83.7            0.0            234.10
# 4      4.706               81.6            0.0             53.59
# ...      ...                ...            ...               ...
# 6131  11.170               80.3            0.0            234.10
# 6132  11.290               82.9            0.0            234.10
# 6133  10.640               83.1            0.0            234.10
# 6134   9.210               83.9            0.0            234.10
# 6135   8.160               81.6            0.0            234.10
#
#       Wind_Direction  Wind_Speed_Avg  ...  Solar_Radiation  Snow_24_Hour  \
# 0             352.00           1.373  ...              NaN           NaN
# 1              19.83           0.816  ...              NaN           NaN
# 2              48.91           0.375  ...              NaN           NaN
# 3             358.60           1.047  ...              NaN           NaN
# 4              53.13           0.015  ...              NaN           NaN
# ...              ...             ...  ...              ...           ...
# 6131          224.40           2.058  ...              NaN           NaN
# 6132          247.70           0.205  ...              NaN           NaN
# 6133          253.30           0.017  ...              NaN           NaN
# 6134          317.30           1.842  ...              NaN           NaN
# 6135          334.70           0.423  ...              NaN           NaN
#
#       Intermittent_Shot_Snow  Net_Solar  Soil_Moisture_A  Soil_Moisture_B  \
# 0                        NaN        NaN              NaN              NaN
# 1                        NaN        NaN              NaN              NaN
# 2                        NaN        NaN              NaN              NaN
# 3                        NaN        NaN              NaN              NaN
# 4                        NaN        NaN              NaN              NaN
# ...                      ...        ...              ...              ...
# 6131                     NaN        NaN              NaN              NaN
# 6132                     NaN        NaN              NaN              NaN
# 6133                     NaN        NaN              NaN              NaN
# 6134                     NaN        NaN              NaN              NaN
# 6135                     NaN        NaN              NaN              NaN
#
#       Soil_Moisture_C  Soil_Temp_A  Soil_Temp_B  Soil_Temp_C
# 0                 NaN          NaN          NaN          NaN
# 1                 NaN          NaN          NaN          NaN
# 2                 NaN          NaN          NaN          NaN
# 3                 NaN          NaN          NaN          NaN
# 4                 NaN          NaN          NaN          NaN
# ...               ...          ...          ...          ...
# 6131              NaN          NaN          NaN          NaN
# 6132              NaN          NaN          NaN          NaN
# 6133              NaN          NaN          NaN          NaN
# 6134              NaN          NaN          NaN          NaN
# 6135              NaN          NaN          NaN          NaN
#
# [14894 rows x 24 columns]

# %%
hurricane_ridge_2022_2 = download_historical_data(
    station_names=["Hurricane Ridge"],
    years=[2021, 2022]
)

hurricane_ridge_2022_2
# Out:
#       Station_Id     Station_Name            Date_Time  Battery_Voltage  \
# 0              4  Hurricane Ridge  2021-12-31 23:00:00             13.2
# 1              4  Hurricane Ridge  2021-12-31 22:00:00             13.2
# 2              4  Hurricane Ridge  2021-12-31 21:00:00             13.2
# 3              4  Hurricane Ridge  2021-12-31 20:00:00             13.2
# 4              4  Hurricane Ridge  2021-12-31 19:00:00             13.2
# ...          ...              ...                  ...              ...
# 6131           4  Hurricane Ridge  2022-01-01 04:00:00             13.2
# 6132           4  Hurricane Ridge  2022-01-01 03:00:00             13.2
# 6133           4  Hurricane Ridge  2022-01-01 02:00:00             13.2
# 6134           4  Hurricane Ridge  2022-01-01 01:00:00             13.2
# 6135           4  Hurricane Ridge  2022-01-01 00:00:00             13.2
#
#         Temp  Relative_Humidity  Precipitation  Total_Snow_Depth  \
# 0      7.331               82.1            0.0            234.10
# 1      5.482               83.1            0.0            234.10
# 2      5.383               82.0            0.0            234.10
# 3      5.132               83.7            0.0            234.10
# 4      4.706               81.6            0.0             53.59
# ...      ...                ...            ...               ...
# 6131  11.170               80.3            0.0            234.10
# 6132  11.290               82.9            0.0            234.10
# 6133  10.640               83.1            0.0            234.10
# 6134   9.210               83.9            0.0            234.10
# 6135   8.160               81.6            0.0            234.10
#
#       Wind_Direction  Wind_Speed_Avg  ...  Solar_Radiation  Snow_24_Hour  \
# 0             352.00           1.373  ...              NaN           NaN
# 1              19.83           0.816  ...              NaN           NaN
# 2              48.91           0.375  ...              NaN           NaN
# 3             358.60           1.047  ...              NaN           NaN
# 4              53.13           0.015  ...              NaN           NaN
# ...              ...             ...  ...              ...           ...
# 6131          224.40           2.058  ...              NaN           NaN
# 6132          247.70           0.205  ...              NaN           NaN
# 6133          253.30           0.017  ...              NaN           NaN
# 6134          317.30           1.842  ...              NaN           NaN
# 6135          334.70           0.423  ...              NaN           NaN
#
#       Intermittent_Shot_Snow  Net_Solar  Soil_Moisture_A  Soil_Moisture_B  \
# 0                        NaN        NaN              NaN              NaN
# 1                        NaN        NaN              NaN              NaN
# 2                        NaN        NaN              NaN              NaN
# 3                        NaN        NaN              NaN              NaN
# 4                        NaN        NaN              NaN              NaN
# ...                      ...        ...              ...              ...
# 6131                     NaN        NaN              NaN              NaN
# 6132                     NaN        NaN              NaN              NaN
# 6133                     NaN        NaN              NaN              NaN
# 6134                     NaN        NaN              NaN              NaN
# 6135                     NaN        NaN              NaN              NaN
#
#       Soil_Moisture_C  Soil_Temp_A  Soil_Temp_B  Soil_Temp_C
# 0                 NaN          NaN          NaN          NaN
# 1                 NaN          NaN          NaN          NaN
# 2                 NaN          NaN          NaN          NaN
# 3                 NaN          NaN          NaN          NaN
# 4                 NaN          NaN          NaN          NaN
# ...               ...          ...          ...          ...
# 6131              NaN          NaN          NaN          NaN
# 6132              NaN          NaN          NaN          NaN
# 6133              NaN          NaN          NaN          NaN
# 6134              NaN          NaN          NaN          NaN
# 6135              NaN          NaN          NaN          NaN
#
# [14894 rows x 24 columns]

# %%
hurricane_ridge_2022_2.equals(hurricane_ridge_2022_1)
# Out:
# True
