# %%
from datetime import date
import pandas as pd
import time

# %% [markdown]
# ## Station Metadata

# %%
stations = pd.read_csv("nwac_stations.csv")
stations
# Out:
#     Station_Id                             Name  Elevation  \
# 0            1                    Alpental Base       3100
# 1            2            Alpental Mid-Mountain       4350
# 2            3                  Alpental Summit       5470
# 3            4                  Hurricane Ridge       5250
# 4            5       Mt Baker - Heather Meadows       4210
# 5            6              Mt Baker - Pan Dome       5020
# 6            7                           Mazama       2170
# 7            8             Washington Pass Base       5450
# 8            9            Washington Pass Upper       6680
# 9           10                Dirty Face Summit       5980
# 10          11                   Lake Wenatchee       1930
# 11          12                  Berne Snow Camp       2700
# 12          13      Stevens Pass - Schmidt Haus       3950
# 13          14       Stevens Pass - Grace Lakes       4800
# 14          17           Stevens Pass - Skyline       5250
# 15          18           Stevens Pass - Skyline       5250
# 16          19                Tumwater Mountain       4180
# 17          20                    Mt Washington       4340
# 18          21                  Snoqualmie Pass       3010
# 19          22    Snoqualmie Pass - Dodge Ridge       3760
# 20          23      Snoqualmie Pass - East Shed       3770
# 21          24               Mission Ridge Base       4610
# 22          25             Mission Ridge Summit       6730
# 23          26       Mission Ridge Mid-Mountain       5160
# 24          27             Crystal Green Valley       6230
# 25          28                     Crystal Base       4570
# 26          29                   Crystal Summit       6830
# 27          30                    Sunrise Upper       6880
# 28          31                     Sunrise Base       6410
# 29          32              Chinook Pass Summit       6240
# 30          33                Chinook Pass Base       5500
# 31          34                        Camp Muir      10110
# 32          35                         Paradise       5400
# 33          36                    Paradise Wind       5380
# 34          37                  White Pass Base       4470
# 35          39                 White Pass Upper       5800
# 36          40        Mt St Helens - Coldwater        3260
# 37          41  Mt Hood Meadows Cascade Express       7300
# 38          42             Mt Hood Meadows Blue       6540
# 39          43             Mt Hood Meadows Base       5380
# 40          44                 Timberline Lodge       5880
# 41          45            Timberline Magic Mile       6990
# 42          46                    Ski Bowl Base       3660
# 43          47                  Ski Bowl Summit       5010
# 44          48                     Blewett Pass       4100
# 45          49          White Pass Pigtail Peak       5970
# 46          50            Stevens Pass - Brooks       4800
#
#                           Location  Start_Date
# 0                  Snoqualmie Pass  2014-10-11
# 1                  Snoqualmie Pass  2014-12-04
# 2                  Snoqualmie Pass  2014-01-03
# 3                         Olympics  2014-09-23
# 4                         Mt Baker  2014-09-23
# 5                         Mt Baker  2014-09-23
# 6                  Washington Pass  2014-01-01
# 7                  Washington Pass  2014-09-23
# 8                  Washington Pass  2014-09-23
# 9   Lake Wenatchee - Mission Ridge  2014-09-23
# 10  Lake Wenatchee - Mission Ridge  2014-09-23
# 11                        Mt Baker  2014-09-23
# 12                    Stevens Pass  2014-09-23
# 13                    Stevens Pass  2014-11-28
# 14                    Stevens Pass  2014-12-23
# 15                    Stevens Pass  2014-12-17
# 16  Lake Wenatchee - Mission Ridge  2014-09-23
# 17                 Snoqualmie Pass  2014-08-01
# 18                 Snoqualmie Pass  2014-08-01
# 19                 Snoqualmie Pass  2014-08-01
# 20                 Snoqualmie Pass  2014-08-01
# 21  Lake Wenatchee - Mission Ridge  2014-01-01
# 22  Lake Wenatchee - Mission Ridge  2014-09-23
# 23  Lake Wenatchee - Mission Ridge  2014-09-23
# 24                      Mt Rainier  2015-01-12
# 25                      Mt Rainier  2014-09-23
# 26                      Mt Rainier  2014-02-02
# 27                      Mt Rainier  2014-09-23
# 28                      Mt Rainier  2014-04-05
# 29                      Mt Rainier  2014-09-23
# 30                      Mt Rainier  2014-09-23
# 31                      Mt Rainier  2014-09-23
# 32                      Mt Rainier  2014-09-23
# 33                      Mt Rainier  2014-09-23
# 34                      White Pass  2020-10-14
# 35                      White Pass  2014-09-23
# 36                    Mt St Helens  2014-09-23
# 37                         Mt Hood  2014-01-03
# 38                         Mt Hood  2014-09-23
# 39                         Mt Hood  2014-09-23
# 40                         Mt Hood  2014-09-23
# 41                         Mt Hood  2014-09-23
# 42                         Mt Hood  2014-10-30
# 43                         Mt Hood  2015-01-08
# 44  Lake Wenatchee - Mission Ridge  2014-10-22
# 45                      White Pass  2014-09-23
# 46                    Stevens Pass  2015-11-26

# %%
stations_list = stations.values.tolist()

# %%
stations_list
# Out:
# [[1, 'Alpental Base', 3100, 'Snoqualmie Pass', '2014-10-11'],
#  [2, 'Alpental Mid-Mountain', 4350, 'Snoqualmie Pass', '2014-12-04'],
#  [3, 'Alpental Summit', 5470, 'Snoqualmie Pass', '2014-01-03'],
#  [4, 'Hurricane Ridge', 5250, 'Olympics', '2014-09-23'],
#  [5, 'Mt Baker - Heather Meadows', 4210, 'Mt Baker', '2014-09-23'],
#  [6, 'Mt Baker - Pan Dome', 5020, 'Mt Baker', '2014-09-23'],
#  [7, 'Mazama', 2170, 'Washington Pass', '2014-01-01'],
#  [8, 'Washington Pass Base', 5450, 'Washington Pass', '2014-09-23'],
#  [9, 'Washington Pass Upper', 6680, 'Washington Pass', '2014-09-23'],
#  [10,
#   'Dirty Face Summit',
#   5980,
#   'Lake Wenatchee - Mission Ridge',
#   '2014-09-23'],
#  [11, 'Lake Wenatchee', 1930, 'Lake Wenatchee - Mission Ridge', '2014-09-23'],
#  [12, 'Berne Snow Camp', 2700, 'Mt Baker', '2014-09-23'],
#  [13, 'Stevens Pass - Schmidt Haus', 3950, 'Stevens Pass', '2014-09-23'],
#  [14, 'Stevens Pass - Grace Lakes', 4800, 'Stevens Pass', '2014-11-28'],
#  [17, 'Stevens Pass - Skyline', 5250, 'Stevens Pass', '2014-12-23'],
#  [18, 'Stevens Pass - Skyline', 5250, 'Stevens Pass', '2014-12-17'],
#  [19,
#   'Tumwater Mountain',
#   4180,
#   'Lake Wenatchee - Mission Ridge',
#   '2014-09-23'],
#  [20, 'Mt Washington', 4340, 'Snoqualmie Pass', '2014-08-01'],
#  [21, 'Snoqualmie Pass', 3010, 'Snoqualmie Pass', '2014-08-01'],
#  [22, 'Snoqualmie Pass - Dodge Ridge', 3760, 'Snoqualmie Pass', '2014-08-01'],
#  [23, 'Snoqualmie Pass - East Shed', 3770, 'Snoqualmie Pass', '2014-08-01'],
#  [24,
#   'Mission Ridge Base',
#   4610,
#   'Lake Wenatchee - Mission Ridge',
#   '2014-01-01'],
#  [25,
#   'Mission Ridge Summit',
#   6730,
#   'Lake Wenatchee - Mission Ridge',
#   '2014-09-23'],
#  [26,
#   'Mission Ridge Mid-Mountain',
#   5160,
#   'Lake Wenatchee - Mission Ridge',
#   '2014-09-23'],
#  [27, 'Crystal Green Valley', 6230, 'Mt Rainier', '2015-01-12'],
#  [28, 'Crystal Base', 4570, 'Mt Rainier', '2014-09-23'],
#  [29, 'Crystal Summit', 6830, 'Mt Rainier', '2014-02-02'],
#  [30, 'Sunrise Upper', 6880, 'Mt Rainier', '2014-09-23'],
#  [31, 'Sunrise Base', 6410, 'Mt Rainier', '2014-04-05'],
#  [32, 'Chinook Pass Summit', 6240, 'Mt Rainier', '2014-09-23'],
#  [33, 'Chinook Pass Base', 5500, 'Mt Rainier', '2014-09-23'],
#  [34, 'Camp Muir', 10110, 'Mt Rainier', '2014-09-23'],
#  [35, 'Paradise', 5400, 'Mt Rainier', '2014-09-23'],
#  [36, 'Paradise Wind', 5380, 'Mt Rainier', '2014-09-23'],
#  [37, 'White Pass Base', 4470, 'White Pass', '2020-10-14'],
#  [39, 'White Pass Upper', 5800, 'White Pass', '2014-09-23'],
#  [40, 'Mt St Helens - Coldwater ', 3260, 'Mt St Helens', '2014-09-23'],
#  [41, 'Mt Hood Meadows Cascade Express', 7300, 'Mt Hood', '2014-01-03'],
#  [42, 'Mt Hood Meadows Blue', 6540, 'Mt Hood', '2014-09-23'],
#  [43, 'Mt Hood Meadows Base', 5380, 'Mt Hood', '2014-09-23'],
#  [44, 'Timberline Lodge', 5880, 'Mt Hood', '2014-09-23'],
#  [45, 'Timberline Magic Mile', 6990, 'Mt Hood', '2014-09-23'],
#  [46, 'Ski Bowl Base', 3660, 'Mt Hood', '2014-10-30'],
#  [47, 'Ski Bowl Summit', 5010, 'Mt Hood', '2015-01-08'],
#  [48, 'Blewett Pass', 4100, 'Lake Wenatchee - Mission Ridge', '2014-10-22'],
#  [49, 'White Pass Pigtail Peak', 5970, 'White Pass', '2014-09-23'],
#  [50, 'Stevens Pass - Brooks', 4800, 'Stevens Pass', '2015-11-26']]

# %%
stations_2 = pd.DataFrame(stations_list, columns=["Station_Id", "Name", "Elevation", "Location", "Start_Date"])
stations_2
# Out:
#     Station_Id                             Name  Elevation  \
# 0            1                    Alpental Base       3100
# 1            2            Alpental Mid-Mountain       4350
# 2            3                  Alpental Summit       5470
# 3            4                  Hurricane Ridge       5250
# 4            5       Mt Baker - Heather Meadows       4210
# 5            6              Mt Baker - Pan Dome       5020
# 6            7                           Mazama       2170
# 7            8             Washington Pass Base       5450
# 8            9            Washington Pass Upper       6680
# 9           10                Dirty Face Summit       5980
# 10          11                   Lake Wenatchee       1930
# 11          12                  Berne Snow Camp       2700
# 12          13      Stevens Pass - Schmidt Haus       3950
# 13          14       Stevens Pass - Grace Lakes       4800
# 14          17           Stevens Pass - Skyline       5250
# 15          18           Stevens Pass - Skyline       5250
# 16          19                Tumwater Mountain       4180
# 17          20                    Mt Washington       4340
# 18          21                  Snoqualmie Pass       3010
# 19          22    Snoqualmie Pass - Dodge Ridge       3760
# 20          23      Snoqualmie Pass - East Shed       3770
# 21          24               Mission Ridge Base       4610
# 22          25             Mission Ridge Summit       6730
# 23          26       Mission Ridge Mid-Mountain       5160
# 24          27             Crystal Green Valley       6230
# 25          28                     Crystal Base       4570
# 26          29                   Crystal Summit       6830
# 27          30                    Sunrise Upper       6880
# 28          31                     Sunrise Base       6410
# 29          32              Chinook Pass Summit       6240
# 30          33                Chinook Pass Base       5500
# 31          34                        Camp Muir      10110
# 32          35                         Paradise       5400
# 33          36                    Paradise Wind       5380
# 34          37                  White Pass Base       4470
# 35          39                 White Pass Upper       5800
# 36          40        Mt St Helens - Coldwater        3260
# 37          41  Mt Hood Meadows Cascade Express       7300
# 38          42             Mt Hood Meadows Blue       6540
# 39          43             Mt Hood Meadows Base       5380
# 40          44                 Timberline Lodge       5880
# 41          45            Timberline Magic Mile       6990
# 42          46                    Ski Bowl Base       3660
# 43          47                  Ski Bowl Summit       5010
# 44          48                     Blewett Pass       4100
# 45          49          White Pass Pigtail Peak       5970
# 46          50            Stevens Pass - Brooks       4800
#
#                           Location  Start_Date
# 0                  Snoqualmie Pass  2014-10-11
# 1                  Snoqualmie Pass  2014-12-04
# 2                  Snoqualmie Pass  2014-01-03
# 3                         Olympics  2014-09-23
# 4                         Mt Baker  2014-09-23
# 5                         Mt Baker  2014-09-23
# 6                  Washington Pass  2014-01-01
# 7                  Washington Pass  2014-09-23
# 8                  Washington Pass  2014-09-23
# 9   Lake Wenatchee - Mission Ridge  2014-09-23
# 10  Lake Wenatchee - Mission Ridge  2014-09-23
# 11                        Mt Baker  2014-09-23
# 12                    Stevens Pass  2014-09-23
# 13                    Stevens Pass  2014-11-28
# 14                    Stevens Pass  2014-12-23
# 15                    Stevens Pass  2014-12-17
# 16  Lake Wenatchee - Mission Ridge  2014-09-23
# 17                 Snoqualmie Pass  2014-08-01
# 18                 Snoqualmie Pass  2014-08-01
# 19                 Snoqualmie Pass  2014-08-01
# 20                 Snoqualmie Pass  2014-08-01
# 21  Lake Wenatchee - Mission Ridge  2014-01-01
# 22  Lake Wenatchee - Mission Ridge  2014-09-23
# 23  Lake Wenatchee - Mission Ridge  2014-09-23
# 24                      Mt Rainier  2015-01-12
# 25                      Mt Rainier  2014-09-23
# 26                      Mt Rainier  2014-02-02
# 27                      Mt Rainier  2014-09-23
# 28                      Mt Rainier  2014-04-05
# 29                      Mt Rainier  2014-09-23
# 30                      Mt Rainier  2014-09-23
# 31                      Mt Rainier  2014-09-23
# 32                      Mt Rainier  2014-09-23
# 33                      Mt Rainier  2014-09-23
# 34                      White Pass  2020-10-14
# 35                      White Pass  2014-09-23
# 36                    Mt St Helens  2014-09-23
# 37                         Mt Hood  2014-01-03
# 38                         Mt Hood  2014-09-23
# 39                         Mt Hood  2014-09-23
# 40                         Mt Hood  2014-09-23
# 41                         Mt Hood  2014-09-23
# 42                         Mt Hood  2014-10-30
# 43                         Mt Hood  2015-01-08
# 44  Lake Wenatchee - Mission Ridge  2014-10-22
# 45                      White Pass  2014-09-23
# 46                    Stevens Pass  2015-11-26

# %%
stations.equals(stations_2)
# Out:
# True

# %%
def stations():
    """Create a Dataframe of NWAC telemetry stations metadata"""
    data = [
        [1, 'Alpental Base', 3100, 'Snoqualmie Pass', '2014-10-11'],
        [2, 'Alpental Mid-Mountain', 4350, 'Snoqualmie Pass', '2014-12-04'],
        [3, 'Alpental Summit', 5470, 'Snoqualmie Pass', '2014-01-03'],
        [4, 'Hurricane Ridge', 5250, 'Olympics', '2014-09-23'],
        [5, 'Mt Baker - Heather Meadows', 4210, 'Mt Baker', '2014-09-23'],
        [6, 'Mt Baker - Pan Dome', 5020, 'Mt Baker', '2014-09-23'],
        [7, 'Mazama', 2170, 'Washington Pass', '2014-01-01'],
        [8, 'Washington Pass Base', 5450, 'Washington Pass', '2014-09-23'],
        [9, 'Washington Pass Upper', 6680, 'Washington Pass', '2014-09-23'],
        [10,
        'Dirty Face Summit',
        5980,
        'Lake Wenatchee - Mission Ridge',
        '2014-09-23'],
        [11, 'Lake Wenatchee', 1930, 'Lake Wenatchee - Mission Ridge', '2014-09-23'],
        [12, 'Berne Snow Camp', 2700, 'Mt Baker', '2014-09-23'],
        [13, 'Stevens Pass - Schmidt Haus', 3950, 'Stevens Pass', '2014-09-23'],
        [14, 'Stevens Pass - Grace Lakes', 4800, 'Stevens Pass', '2014-11-28'],
        [17, 'Stevens Pass - Skyline', 5250, 'Stevens Pass', '2014-12-23'],
        [18, 'Stevens Pass - Skyline', 5250, 'Stevens Pass', '2014-12-17'],
        [19,
        'Tumwater Mountain',
        4180,
        'Lake Wenatchee - Mission Ridge',
        '2014-09-23'],
        [20, 'Mt Washington', 4340, 'Snoqualmie Pass', '2014-08-01'],
        [21, 'Snoqualmie Pass', 3010, 'Snoqualmie Pass', '2014-08-01'],
        [22, 'Snoqualmie Pass - Dodge Ridge', 3760, 'Snoqualmie Pass', '2014-08-01'],
        [23, 'Snoqualmie Pass - East Shed', 3770, 'Snoqualmie Pass', '2014-08-01'],
        [24,
        'Mission Ridge Base',
        4610,
        'Lake Wenatchee - Mission Ridge',
        '2014-01-01'],
        [25,
        'Mission Ridge Summit',
        6730,
        'Lake Wenatchee - Mission Ridge',
        '2014-09-23'],
        [26,
        'Mission Ridge Mid-Mountain',
        5160,
        'Lake Wenatchee - Mission Ridge',
        '2014-09-23'],
        [27, 'Crystal Green Valley', 6230, 'Mt Rainier', '2015-01-12'],
        [28, 'Crystal Base', 4570, 'Mt Rainier', '2014-09-23'],
        [29, 'Crystal Summit', 6830, 'Mt Rainier', '2014-02-02'],
        [30, 'Sunrise Upper', 6880, 'Mt Rainier', '2014-09-23'],
        [31, 'Sunrise Base', 6410, 'Mt Rainier', '2014-04-05'],
        [32, 'Chinook Pass Summit', 6240, 'Mt Rainier', '2014-09-23'],
        [33, 'Chinook Pass Base', 5500, 'Mt Rainier', '2014-09-23'],
        [34, 'Camp Muir', 10110, 'Mt Rainier', '2014-09-23'],
        [35, 'Paradise', 5400, 'Mt Rainier', '2014-09-23'],
        [36, 'Paradise Wind', 5380, 'Mt Rainier', '2014-09-23'],
        [37, 'White Pass Base', 4470, 'White Pass', '2020-10-14'],
        [39, 'White Pass Upper', 5800, 'White Pass', '2014-09-23'],
        [40, 'Mt St Helens - Coldwater ', 3260, 'Mt St Helens', '2014-09-23'],
        [41, 'Mt Hood Meadows Cascade Express', 7300, 'Mt Hood', '2014-01-03'],
        [42, 'Mt Hood Meadows Blue', 6540, 'Mt Hood', '2014-09-23'],
        [43, 'Mt Hood Meadows Base', 5380, 'Mt Hood', '2014-09-23'],
        [44, 'Timberline Lodge', 5880, 'Mt Hood', '2014-09-23'],
        [45, 'Timberline Magic Mile', 6990, 'Mt Hood', '2014-09-23'],
        [46, 'Ski Bowl Base', 3660, 'Mt Hood', '2014-10-30'],
        [47, 'Ski Bowl Summit', 5010, 'Mt Hood', '2015-01-08'],
        [48, 'Blewett Pass', 4100, 'Lake Wenatchee - Mission Ridge', '2014-10-22'],
        [49, 'White Pass Pigtail Peak', 5970, 'White Pass', '2014-09-23'],
        [50, 'Stevens Pass - Brooks', 4800, 'Stevens Pass', '2015-11-26']
    ]
    return pd.DataFrame(data, columns=["Station_Id", "Name", "Elevation", "Location", "Start_Date"])

# %%
stations()
# Out:
#     Station_Id                             Name  Elevation  \
# 0            1                    Alpental Base       3100
# 1            2            Alpental Mid-Mountain       4350
# 2            3                  Alpental Summit       5470
# 3            4                  Hurricane Ridge       5250
# 4            5       Mt Baker - Heather Meadows       4210
# 5            6              Mt Baker - Pan Dome       5020
# 6            7                           Mazama       2170
# 7            8             Washington Pass Base       5450
# 8            9            Washington Pass Upper       6680
# 9           10                Dirty Face Summit       5980
# 10          11                   Lake Wenatchee       1930
# 11          12                  Berne Snow Camp       2700
# 12          13      Stevens Pass - Schmidt Haus       3950
# 13          14       Stevens Pass - Grace Lakes       4800
# 14          17           Stevens Pass - Skyline       5250
# 15          18           Stevens Pass - Skyline       5250
# 16          19                Tumwater Mountain       4180
# 17          20                    Mt Washington       4340
# 18          21                  Snoqualmie Pass       3010
# 19          22    Snoqualmie Pass - Dodge Ridge       3760
# 20          23      Snoqualmie Pass - East Shed       3770
# 21          24               Mission Ridge Base       4610
# 22          25             Mission Ridge Summit       6730
# 23          26       Mission Ridge Mid-Mountain       5160
# 24          27             Crystal Green Valley       6230
# 25          28                     Crystal Base       4570
# 26          29                   Crystal Summit       6830
# 27          30                    Sunrise Upper       6880
# 28          31                     Sunrise Base       6410
# 29          32              Chinook Pass Summit       6240
# 30          33                Chinook Pass Base       5500
# 31          34                        Camp Muir      10110
# 32          35                         Paradise       5400
# 33          36                    Paradise Wind       5380
# 34          37                  White Pass Base       4470
# 35          39                 White Pass Upper       5800
# 36          40        Mt St Helens - Coldwater        3260
# 37          41  Mt Hood Meadows Cascade Express       7300
# 38          42             Mt Hood Meadows Blue       6540
# 39          43             Mt Hood Meadows Base       5380
# 40          44                 Timberline Lodge       5880
# 41          45            Timberline Magic Mile       6990
# 42          46                    Ski Bowl Base       3660
# 43          47                  Ski Bowl Summit       5010
# 44          48                     Blewett Pass       4100
# 45          49          White Pass Pigtail Peak       5970
# 46          50            Stevens Pass - Brooks       4800
#
#                           Location  Start_Date
# 0                  Snoqualmie Pass  2014-10-11
# 1                  Snoqualmie Pass  2014-12-04
# 2                  Snoqualmie Pass  2014-01-03
# 3                         Olympics  2014-09-23
# 4                         Mt Baker  2014-09-23
# 5                         Mt Baker  2014-09-23
# 6                  Washington Pass  2014-01-01
# 7                  Washington Pass  2014-09-23
# 8                  Washington Pass  2014-09-23
# 9   Lake Wenatchee - Mission Ridge  2014-09-23
# 10  Lake Wenatchee - Mission Ridge  2014-09-23
# 11                        Mt Baker  2014-09-23
# 12                    Stevens Pass  2014-09-23
# 13                    Stevens Pass  2014-11-28
# 14                    Stevens Pass  2014-12-23
# 15                    Stevens Pass  2014-12-17
# 16  Lake Wenatchee - Mission Ridge  2014-09-23
# 17                 Snoqualmie Pass  2014-08-01
# 18                 Snoqualmie Pass  2014-08-01
# 19                 Snoqualmie Pass  2014-08-01
# 20                 Snoqualmie Pass  2014-08-01
# 21  Lake Wenatchee - Mission Ridge  2014-01-01
# 22  Lake Wenatchee - Mission Ridge  2014-09-23
# 23  Lake Wenatchee - Mission Ridge  2014-09-23
# 24                      Mt Rainier  2015-01-12
# 25                      Mt Rainier  2014-09-23
# 26                      Mt Rainier  2014-02-02
# 27                      Mt Rainier  2014-09-23
# 28                      Mt Rainier  2014-04-05
# 29                      Mt Rainier  2014-09-23
# 30                      Mt Rainier  2014-09-23
# 31                      Mt Rainier  2014-09-23
# 32                      Mt Rainier  2014-09-23
# 33                      Mt Rainier  2014-09-23
# 34                      White Pass  2020-10-14
# 35                      White Pass  2014-09-23
# 36                    Mt St Helens  2014-09-23
# 37                         Mt Hood  2014-01-03
# 38                         Mt Hood  2014-09-23
# 39                         Mt Hood  2014-09-23
# 40                         Mt Hood  2014-09-23
# 41                         Mt Hood  2014-09-23
# 42                         Mt Hood  2014-10-30
# 43                         Mt Hood  2015-01-08
# 44  Lake Wenatchee - Mission Ridge  2014-10-22
# 45                      White Pass  2014-09-23
# 46                    Stevens Pass  2015-11-26

# %% [markdown]
# ## Historical telemetry

# %%
def download_station_data(station_id, year, simple_column_names=True):
    """Download one year's worth of station data"""
    nwac_telemetry_cols = {
        'id'                              : "Station_Id",
        'Relative Humidity  (%) '         : "Relative_Humidity",
        'Solar Radiation  (W/m2) '        : "Solar_Radiation",
        '24 Hour Snow  (") '              : "Snow_24_Hour",
        'Soil Moisture C  (VWC) '         : "Soil_Moisture_C",
        'Date/Time (PST)'                 : "Date_Time",
        'Wind Direction  (deg.) '         : "Wind_Direction",
        'Net Solar  (mJ/m2) '             : "Net_Solar",
        'Wind Speed Maximum  (mph) '      : "Wind_Speed_Max",
        'Wind Speed Minimum  (mph) '      : "Wind_Speed_Min",
        'Wind Speed Average  (mph) '      : "Wind_Speed_Avg",
        'Soil Temperature B  (deg F) '    : "Soil_Temp_B",
        'Barometric Pressure  (mb) '      : "Pressure",
        'Soil Temperature A  (deg F) '    : "Soil_Temp_A",
        'Soil Moisture B  (VWC) '         : "Soil_Moisture_B",
        'Battery Voltage  (v) '           : "Battery_Voltage",
        'Soil Moisture A  (VWC) '         : "Soil_Moisture_A",
        'Precipitation  (") '             : "Precipitation",
        'Equipment Temperature  (deg F) ' : "Equipment_Temperature",
        'Total Snow Depth  (") '          : "Total_Snow_Depth",
        'Intermittent/Shot Snow  (") '    : "Intermittent_Shot_Snow",
        'Soil Temperature C  (deg F) '    : "Soil_Temp_C",
        'Temperature  (deg F) '           : "Temp",  
    }
    url = f"http://www.nwac.us/data-portal/csv/q/?datalogger_id={station_id}&year={year}"
    data = pd.read_csv(url)
    if simple_column_names:
        data = data.rename(columns=nwac_telemetry_cols)
    return data


hurricane_ridge_2022 = download_station_data(station_id=4, year=2022, simple_column_names=True)

# %%
hurricane_ridge_2022.head()
# Out:
#              Date_Time  Battery_Voltage   Temp  Relative_Humidity  \
# 0  2022-09-12 14:00:00            13.15  64.84              41.09
# 1  2022-09-12 13:00:00            13.16  65.67              25.76
# 2  2022-09-12 12:00:00            13.16  63.66              30.04
# 3  2022-09-12 11:00:00            13.17  62.58              31.52
# 4  2022-09-12 10:00:00            13.17  59.26              29.34
#
#    Precipitation  Total_Snow_Depth  Wind_Direction  Wind_Speed_Avg  \
# 0            0.0             6.988           223.5           3.646
# 1            0.0            -3.605           226.2           5.463
# 2            0.0             7.806           226.8           5.057
# 3            0.0             6.993           224.1           5.899
# 4            0.0            11.630           227.0           6.516
#
#    Wind_Speed_Min  Wind_Speed_Max  ...  Solar_Radiation  Snow_24_Hour  \
# 0           0.000           7.814  ...              NaN           NaN
# 1           1.461           9.750  ...              NaN           NaN
# 2           1.325           9.650  ...              NaN           NaN
# 3           2.005          10.160  ...              NaN           NaN
# 4           2.379          14.000  ...              NaN           NaN
#
#    Intermittent_Shot_Snow  Net_Solar  Soil_Moisture_A  Soil_Moisture_B  \
# 0                     NaN        NaN              NaN              NaN
# 1                     NaN        NaN              NaN              NaN
# 2                     NaN        NaN              NaN              NaN
# 3                     NaN        NaN              NaN              NaN
# 4                     NaN        NaN              NaN              NaN
#
#    Soil_Moisture_C  Soil_Temp_A  Soil_Temp_B  Soil_Temp_C
# 0              NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN
#
# [5 rows x 22 columns]

# %%
def download_historical_data(station_ids=None, station_names=None, years=None, 
                             simple_column_names=True, verbose=False):
    """Download historical NWAC station telemetry data for multiple stations/years
    
    Parameters
    ----------
    
    station_ids : list (optional) (default is all)
        A list of one or more NWAC station ids. Please only use one of station_ids
        or station_names but not both. If unspecified, the default will be
        all stations.
        
    station_names : list (optional) (default is all)
        A list of one or more NWAC station names. Please only use one of station_ids
        or station_names but not both. If unspecified, the default will be be all 
        stations. 
        
    years : list (optional)
        A list of one or more years to download data for. The first year of data
        availabilty, although 2015 data is more complete and reliable. 
        
    simple_column_names : bool (default is True)
        Transform the long column names into more readable ones. 
        
    verbose : bool (default is False)
        Show verbose download progress

    Returns
    -------
    nwac_data : pd.DataFrame
        A DataFrame of historical NWAC telemetry data
    
    """
    
    # Assertations
    all_stations = stations()
    assert ((station_ids is not None) + (station_names is not None)) < 2
    if station_ids is not None:
        assert isinstance(station_ids, list)
        assert all([station_id in all_stations["Station_Id"] for station_id in station_ids])
    elif station_names is not None:
        assert isinstance(station_names, list)
        assert all([station_name in all_stations["Name"] for station_name in station_names])
    else:
        station_ids = list(all_stations["Station_Id"].unique())
    if years is not None:
        assert isinstance(years, list)
        years = [int(year) for year in years]
        assert min(years) >= 2014
    else:
        current_year = date.today().year
        years = list(range(2014, current_year + 1))
    
    # Transform station ids to names and vice versa
    station_id_to_name = dict(zip(all_stations["Station_Id"], all_stations["Name"]))
    station_name_to_id = dict(zip(all_stations["Name"], all_stations["Station_Id"]))
    if station_ids is None:
        station_ids = [station_name_to_id[station_name] for station_name in station_names]
    
    # Download the data
    station_years_data = []
    for year in years:
        if verbose:
            print("Downloading data for year:", year)
        for station_id in station_ids:
            if verbose:
                print("> Downloading data for station:", station_id_to_name[station_id])
            station_year_data = download_station_data(
                station_id=station_id, 
                year=year, 
                simple_column_names=simple_column_names
            )
            existing_columns = list(station_year_data)
            station_year_data = (
                station_year_data
                .assign(Station_Id=station_id)
                .assign(Station_Name=station_id_to_name[station_id])
            )
            station_year_data = station_year_data[["Station_Id", "Station_Name"] + existing_columns]
            time.sleep(0.5)  # -- small gaps in pinging the server
            station_years_data.append(station_year_data)
    if verbose:
        print("Download completed!")
    return pd.concat(station_years_data)



all_data = download_historical_data(
    station_ids=[4, 7], 
    station_names=None, 
    years=[2014, 2022], 
    simple_column_names=True, 
    verbose=True
)
# Out:
# Downloading data for year: 2014
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mazama
# Downloading data for year: 2022
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mazama
# Download completed!

# %%
all_data.head()
# Out:
#    Station_Id     Station_Name            Date_Time  Battery_Voltage   Temp  \
# 0           4  Hurricane Ridge  2014-12-31 23:00:00            12.99  39.42
# 1           4  Hurricane Ridge  2014-12-31 22:00:00            13.00  40.13
# 2           4  Hurricane Ridge  2014-12-31 21:00:00            12.99  37.99
# 3           4  Hurricane Ridge  2014-12-31 20:00:00            12.99  38.46
# 4           4  Hurricane Ridge  2014-12-31 19:00:00            12.99  38.58
#
#    Relative_Humidity  Precipitation  Total_Snow_Depth  Wind_Direction  \
# 0              54.72            0.0             22.54            0.00
# 1              53.33            0.0             22.02            8.55
# 2              48.82            0.0             22.41           77.30
# 3              45.71            0.0             22.29           35.92
# 4              39.28            0.0             22.42           39.27
#
#    Wind_Speed_Avg  ...  Solar_Radiation  Snow_24_Hour  Intermittent_Shot_Snow  \
# 0           0.000  ...              NaN           NaN                     NaN
# 1           0.342  ...              NaN           NaN                     NaN
# 2           0.019  ...              NaN           NaN                     NaN
# 3           1.186  ...              NaN           NaN                     NaN
# 4           0.928  ...              NaN           NaN                     NaN
#
#    Net_Solar  Soil_Moisture_A  Soil_Moisture_B  Soil_Moisture_C  Soil_Temp_A  \
# 0        NaN              NaN              NaN              NaN          NaN
# 1        NaN              NaN              NaN              NaN          NaN
# 2        NaN              NaN              NaN              NaN          NaN
# 3        NaN              NaN              NaN              NaN          NaN
# 4        NaN              NaN              NaN              NaN          NaN
#
#    Soil_Temp_B  Soil_Temp_C
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 24 columns]

# %%
# %%time


all_data = download_historical_data(
    station_ids=None, 
    station_names=None, 
    years=None, 
    simple_column_names=True, 
    verbose=True
)
# Out:
# Downloading data for year: 2014
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2015
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2016
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2017
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2018
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2019
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2020
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2021
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Downloading data for year: 2022
# > Downloading data for station: Alpental Base
# > Downloading data for station: Alpental Mid-Mountain
# > Downloading data for station: Alpental Summit
# > Downloading data for station: Hurricane Ridge
# > Downloading data for station: Mt Baker - Heather Meadows
# > Downloading data for station: Mt Baker - Pan Dome
# > Downloading data for station: Mazama
# > Downloading data for station: Washington Pass Base
# > Downloading data for station: Washington Pass Upper
# > Downloading data for station: Dirty Face Summit
# > Downloading data for station: Lake Wenatchee
# > Downloading data for station: Berne Snow Camp
# > Downloading data for station: Stevens Pass - Schmidt Haus
# > Downloading data for station: Stevens Pass - Grace Lakes
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Stevens Pass - Skyline
# > Downloading data for station: Tumwater Mountain
# > Downloading data for station: Mt Washington
# > Downloading data for station: Snoqualmie Pass
# > Downloading data for station: Snoqualmie Pass - Dodge Ridge
# > Downloading data for station: Snoqualmie Pass - East Shed
# > Downloading data for station: Mission Ridge Base
# > Downloading data for station: Mission Ridge Summit
# > Downloading data for station: Mission Ridge Mid-Mountain
# > Downloading data for station: Crystal Green Valley
# > Downloading data for station: Crystal Base
# > Downloading data for station: Crystal Summit
# > Downloading data for station: Sunrise Upper
# > Downloading data for station: Sunrise Base
# > Downloading data for station: Chinook Pass Summit
# > Downloading data for station: Chinook Pass Base
# > Downloading data for station: Camp Muir
# > Downloading data for station: Paradise
# > Downloading data for station: Paradise Wind
# > Downloading data for station: White Pass Base
# > Downloading data for station: White Pass Upper
# > Downloading data for station: Mt St Helens - Coldwater
# > Downloading data for station: Mt Hood Meadows Cascade Express
# > Downloading data for station: Mt Hood Meadows Blue
# > Downloading data for station: Mt Hood Meadows Base
# > Downloading data for station: Timberline Lodge
# > Downloading data for station: Timberline Magic Mile
# > Downloading data for station: Ski Bowl Base
# > Downloading data for station: Ski Bowl Summit
# > Downloading data for station: Blewett Pass
# > Downloading data for station: White Pass Pigtail Peak
# > Downloading data for station: Stevens Pass - Brooks
# Download completed!
# CPU times: user 45.3 s, sys: 3.86 s, total: 49.2 s
# Wall time: 8min 48s
